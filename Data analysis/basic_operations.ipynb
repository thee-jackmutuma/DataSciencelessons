# %%
print ("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
# read the csv file into a dataframe
df = pd.read_csv("Health_Facilities.csv")

# %%
df.shape
# Out:
# (6762, 15)

# %%
df.columns.tolist()
# Out:
# ['Facility Number',
#  'Facility Name',
#  'HMIS',
#  'Province',
#  'District',
#  'Division',
#  'LOCATION',
#  'County',
#  'Constituency',
#  'Sub-Location',
#  'Spatial Reference Method',
#  'Facility Type',
#  'Agency',
#  'Geolocation',
#  'Facility Type NAME']

# %%
df
# Out:
#       Facility Number                      Facility Name  HMIS     Province  \
# 0                  29           KIAMBU DISTRICT HOSPITAL   251      CENTRAL
# 1                  36                    KIJABE HOSPITAL   252      CENTRAL
# 2                  51                  NAZARETH HOSPITAL   255      CENTRAL
# 3                  62           P.C.E.A. KIKUYU HOSPITAL  2441      CENTRAL
# 4                  66       TIGONI SUB-DISTRICT HOSPITAL   257      CENTRAL
# ...               ...                                ...   ...          ...
# 6757               85                   POST OFFICE DISP  3613  RIFT VALLEY
# 6758               62                   NZOIA SUGAR DISP  2220      WESTERN
# 6759               34  ST. CATHERINE SPECIAL SCHOOL DISP  2356      WESTERN
# 6760                0               FRAMO MEDICAL CLINIC     0       NYANZA
# 6761               62                     CENTRAL CLINIC     0      WESTERN
#
#            District Division        LOCATION  County   Constituency  \
# 0            KIAMBU  KIAMBAA  KIAMBAA S/AREA  KIAMBU  GATUNDU NORTH
# 1            KIAMBU     LARI          KIJABE  KIAMBU  GATUNDU NORTH
# 2            KIAMBU   LIMURU      KARAMBAINI  KIAMBU  GATUNDU NORTH
# 3            KIAMBU   KIKUYU          KIKUYU  KIAMBU  GATUNDU NORTH
# 4            KIAMBU   LIMURU          TIGONI  KIAMBU  GATUNDU NORTH
# ...             ...      ...             ...     ...            ...
# 6757    UASIN GISHU      NaN             NaN     NaN            NaN
# 6758        BUNGOMA      NaN             NaN     NaN            NaN
# 6759          BUSIA      NaN             NaN     NaN            NaN
# 6760    KISII NORTH      NaN             NaN     NaN            NaN
# 6761  BUTERE/MUMIAS      NaN             NaN     NaN            NaN
#
#            Sub-Location Spatial Reference Method  Facility Type Agency  \
# 0     TOWNSHIP(KIAMBAA)                      GPS              1    MOH
# 1                KIJABE                      GPS              1   MISS
# 2            KARAMBAINI             1:50000 MAPS              1   MISS
# 3       KIKUYU TOWNSHIP                      DDP              1   MISS
# 4       ITHANJI(KIAMBU)                      DDP              1    MOH
# ...                 ...                      ...            ...    ...
# 6757                NaN                      NaN              9   PRIV
# 6758                NaN                      NaN              9   PRIV
# 6759                NaN                      NaN              9   MISS
# 6760                NaN                      NaN              0    NaN
# 6761                NaN                      NaN              0    NaN
#
#                            Geolocation  \
# 0     (-1.16938000000, 36.82993000000)
# 1     (-0.94349000000, 36.59431000000)
# 2     (-1.13378000000, 36.72570000000)
# 3     (-1.26667000000, 36.66670000000)
# 4     (-1.12859000000, 36.64930000000)
# ...                                ...
# 6757                    (0E-11, 0E-11)
# 6758                    (0E-11, 0E-11)
# 6759                    (0E-11, 0E-11)
# 6760                    (0E-11, 0E-11)
# 6761                    (0E-11, 0E-11)
#
#                                      Facility Type NAME
# 0     Hospital Moh and Mission Districts, sub-districts
# 1     Hospital Moh and Mission Districts, sub-districts
# 2     Hospital Moh and Mission Districts, sub-districts
# 3     Hospital Moh and Mission Districts, sub-districts
# 4     Hospital Moh and Mission Districts, sub-districts
# ...                                                 ...
# 6757  Institutions Health Facilities - schools, Univ...
# 6758  Institutions Health Facilities - schools, Univ...
# 6759  Institutions Health Facilities - schools, Univ...
# 6760                                                NaN
# 6761                                                NaN
#
# [6762 rows x 15 columns]

# %%
#check for missing values
df.isnull().sum()
# Out:
# Facility Number                0
# Facility Name                  2
# HMIS                           0
# Province                       2
# District                       2
# Division                    1680
# LOCATION                    1756
# County                      1907
# Constituency                1907
# Sub-Location                1780
# Spatial Reference Method    1895
# Facility Type                  0
# Agency                         2
# Geolocation                    0
# Facility Type NAME             2
# dtype: int64

# %%
#check for missing values in each column
df.isnull().sum()/len(df)*100
# Out:
# Facility Number              0.000000
# Facility Name                0.029577
# HMIS                         0.000000
# Province                     0.029577
# District                     0.029577
# Division                    24.844720
# LOCATION                    25.968648
# County                      28.201715
# Constituency                28.201715
# Sub-Location                26.323573
# Spatial Reference Method    28.024253
# Facility Type                0.000000
# Agency                       0.029577
# Geolocation                  0.000000
# Facility Type NAME           0.029577
# dtype: float64

# %%
df.dtypes
# Out:
# Facility Number              int64
# Facility Name               object
# HMIS                         int64
# Province                    object
# District                    object
# Division                    object
# LOCATION                    object
# County                      object
# Constituency                object
# Sub-Location                object
# Spatial Reference Method    object
# Facility Type                int64
# Agency                      object
# Geolocation                 object
# Facility Type NAME          object
# dtype: object
